# %% [markdown]
# <a href="https://colab.research.google.com/github/SOUMYADEEPDEY1217/IIT-GUWAHATI-AI-ML-SUMMER-SCHOOL-2026/blob/main/IIT_GUWAHATI_AI_ML_SUMMER_SCHOOL_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DEMONSTRATION 1**

# %% [markdown]
# **Problem 1:**
#
# Taking User Input & Understanding Types Ask the user for their age and display it along with its data type.

# %%
age = int(input("Enter your age: "))
print("Your age is:", age)
print("Data type of age:", type(age))
# Out:
# Enter your age: 21
# Your age is: 21
# Data type of age: <class 'int'>

# %% [markdown]
# **Problem 2:**
#
# Simple Calculator (with Safety Check) Problem: Create a calculator that performs addition, subtraction, multiplication, or division.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operation (+, -, *, /): ")

if operator == '+':
    print("Result:", num1 + num2)
elif operator == '-':
    print("Result:", num1 - num2)
elif operator == '*':
    print("Result:", num1 * num2)
elif operator == '/':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Division by zero is not allowed")
else:
    print("Invalid operator")
# Out:
# Enter first number: 12
# Enter second number: 17
# Enter operation (+, -, *, /): +
# Result: 29.0

# %% [markdown]
# **Problem 3:**
#
# Even or Odd Checker Problem: Check whether a given number is even or odd.

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# Enter a number: 12
# The number is Even

# %% [markdown]
# **Problem 4:**
#
# Maximum of Two Numbers Problem: Find the larger of two numbers entered by the user.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
if num1 > num2:
    print("Greater number is:", num1)
elif num2 > num1:
    print("Greater number is:", num2)
else:
    print("Both numbers are equal")
# Out:
# Enter first number: 12
# Enter second number: 17
# Greater number is: 17.0

# %% [markdown]
# **Problem 5:**
#
# Grade Classification System Problem: Assign grades based on marks entered by the student.

# %%
marks = int(input("Enter your marks (0-100): "))
if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
elif marks >= 60:
    print("Grade: C")
else:
    print("Grade: D")
# Out:
# Enter your marks (0-100): 90
# Grade: A

# %% [markdown]
# **Problem 6:**
#
# Sum of First N Natural Numbers Problem: Calculate the sum of the first n natural numbers

# %%
n = int(input("Enter a number: "))
total = 0
for i in range(1, n + 1):
    total += i
print("Sum of first", n, "natural numbers is:", total)
# Out:
# Enter a number: 12
# Sum of first 12 natural numbers is: 78

# %% [markdown]
# **Problem 7:**
#
# Multiplication Table Problem: Print the multiplication table of a given number.

# %%
number = int(input("Enter a number: "))
for i in range(1, 11):
    print(number, "x", i, "=", number * i)
# Out:
# Enter a number: 12
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120

# %% [markdown]
# **Problem 8:**
#
# Count Positive, Negative, and Zero Problem: Take 5 numbers from the user and count positives, negatives, and zeros.

# %%
positive = negative = zero = 0
for i in range(5):
    num = int(input("Enter number: "))
    if num > 0:
        positive += 1
    elif num < 0:
        negative += 1
    else:
        zero += 1
print("Positive:", positive)
print("Negative:", negative)
print("Zero:", zero)
# Out:
# Enter number: 12
# Enter number: 12
# Enter number: 14
# Enter number: 17
# Enter number: 21
# Positive: 5
# Negative: 0
# Zero: 0

# %% [markdown]
# **Problem 9:**
#
# Simple Login Validation Problem: Check whether username and password match predefined values.

# %%
stored_username = "admin"
stored_password = "python123"
username = input("Enter username: ")
password = input("Enter password: ")
if username == stored_username and password == stored_password:
    print("Login successful")
else:
    print("Invalid credentials")
# Out:
# Enter username: admin
# Enter password: python123
# Login successful

# %% [markdown]
# **Problem 10:**
#
# Finding the Largest Number in a List

# %%
numbers = []
for i in range(5):
    numbers.append(int(input("Enter number: ")))
print("Largest number is:", max(numbers))
# Out:
# Enter number: 12
# Enter number: 14
# Enter number: 17
# Enter number: 15
# Enter number: 14
# Largest number is: 17

# %% [markdown]
# # **DEMONSTRATION 2**

# %% [markdown]
# **Question 1:**
#
# Given a variable x = 5, perform conditional checks to print specific messages:
# * a. Print 'Smaller' if x < 10
# * b. Print 'Bigger' if x > 20
# * c. Always print 'Finish' at the end

# %%
x = 5

if x < 10:
    print("Smaller")
if x > 20:
    print("Bigger")
print("Finish")
# Out:
# Smaller
# Finish

# %% [markdown]
# **Question 2:**
#
# Use membership operators to check if certain animals exist in tuples.
# * a. Check if 'horse' is in a tuple
# * b. If true, check if 'cat' exists in another tuple
# * c. If 'sheep' is not in a tuple, print accordingly

# %%
if 'horse' in ('dog', 'cat', 'horse', 'penguin'):
    print('horse exists')
    if 'cat' in ('dog', 'cat', 'sheep'):
        print('cat exist')
        if 'sheep' not in ('dog', 'cat', 'horse', 'penguin'):
            print('sheep does not exist')
# Out:
# horse exists
# cat exist
# sheep does not exist

# %% [markdown]
# **Question 3:**
#
# Take three numbers from the user and find the biggest using nested if statements.
# * a. Identify the largest number among 3 inputs
# * b. Understand the structure of nested if-else

# %%
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
c = int(input("Enter Third Number: "))

if a > b:
    if a > c:
        print(a, "is Big")
    else:
        print(c, "is Big")
else:
    if b > c:
        print(b, "is Big")
    else:
        print(c, "is Big")
# Out:
# Enter First Number: 12
# Enter Second Number: 17
# Enter Third Number: 21
# 21 is Big

# %% [markdown]
# **Question 4:**
#
# Check the value of price and print a message depending on whether it's less than, greater than, or equal to 100.
# * a. What is the output when price = 100?
# * b. Modify price and observe changes

# %%
price = 100

if price > 100:
    print("price is greater than 100")
elif price == 100:
    print("price is 100")
elif price < 100:
    print("price is less than 100")
else:
    print("Am in else block")
# Out:
# price is 100

# %% [markdown]
# **Question 5:**
#
# Determine a person's status based on age, graduation, and license status using nested conditions.
# * a. Print a message if the person is 18 or older
# * b. If graduated, print a congratulatory message
# * c. If has license, print a driving-related message

# %%
age = 19
isGraduated = False
hasLicense = True

if age >= 18:
    print("You're 18 or older. Welcome to adulthood!")
    if isGraduated:
        print("Congratulations with your graduation!")
    if hasLicense:
        print("Happy driving!")
# Out:
# You're 18 or older. Welcome to adulthood!
# Happy driving!

# %% [markdown]
# **Question 6:**
#
# Check if a variable is within, equal to, or less than certain values using multiple if, elif, and else blocks.
# * a. What is printed when var = 100?
# * b. Try with var = 150 and observe output

# %%
var = 100

if var < 200:
    print("Expression value is less than 200")

if var == 150:
    print("Which is 150")
elif var == 100:
    print("Which is 100")
elif var == 50:
    print("Which is 50")
elif var < 50:
    print("Expression value is less than 50")
else:
    print("Could not find true expression")

print("Good bye!")
# Out:
# Expression value is less than 200
# Which is 100
# Good bye!

# %%
animals = ('dog', 'cat', 'horse')
if 'cow' in animals:
    print('cow found')
elif 'horse' in animals:
    print('horse found')
else:
    print('none')
# Out:
# horse found

# %% [markdown]
# # **DEMONSTRATION 3**

# %% [markdown]
# Problem 1: Student Records Challenge
#
# Given a nested list of student records, write code to:
#
# students = [
#     ["Alice", "Physics", 85],
#     ["Bob", "Chemistry", 78],
#     ["Cara", "Maths", 92]
# ]
#
# a. Print just the names and scores of all students.
# b. Add a new student record ["Dave", "Biology", 88] at the end.
# c. Update Bob's score to 82.

# %%
students = [
    ["Alice", "Physics", 85],
    ["Bob", "Chemistry", 78],
    ["Cara", "Maths", 92]
]

# a. Print just the names and scores of all students
for student in students:
    print(student[0], student[2])

# b. Add a new student record ["Dave", "Biology", 88] at the end
students.append(["Dave", "Biology", 88])
print(students)

# c. Update Bob's score to 82
for student in students:
    if student[0] == "Bob":
        student[2] = 82
print(students)
# Out:
# Alice 85
# Bob 78
# Cara 92
# [['Alice', 'Physics', 85], ['Bob', 'Chemistry', 78], ['Cara', 'Maths', 92], ['Dave', 'Biology', 88]]
# [['Alice', 'Physics', 85], ['Bob', 'Chemistry', 82], ['Cara', 'Maths', 92], ['Dave', 'Biology', 88]]

# %% [markdown]
# Problem 2: Modify a Sensor Readings List
#
# Modify a Sensor Readings List
# You have a list of readings from a temperature sensor every hour:
#
# readings = [23, 25, 24, 22, 26, 27, 28, 29]
#
# a. The sensor misreported the third and fourth hours: replace readings at indices 2 and 3 with [24, 23].
# b. Append a final reading of 30.
# c. Use a list method to find how many times the value 24 appears.

# %%
readings = [23, 25, 24, 22, 26, 27, 28, 29]

# a. Replace readings at indices 2 and 3 with [24, 23]
readings[2:4] = [24, 23]
print(readings)

# b. Append a final reading of 30
readings.append(30)
print(readings)

# c. Find how many times the value 24 appears
print(readings.count(24))
# Out:
# [23, 25, 24, 23, 26, 27, 28, 29]
# [23, 25, 24, 23, 26, 27, 28, 29, 30]
# 1

# %% [markdown]
# Problem 3: String Slicing & Indexing - Device ID Parser
#
# String Slicing & Indexing - Device ID Parser
# Given a device ID string:
#
# device_id = "SN-A1B2C3D4E5"
#
# a. Extract the serial prefix ("SN-") and suffix ("A1B2C3D4E5") using slicing.
# b. Retrieve just the last three characters ("4E5") using negative indexing.
# c. Reverse the entire string using slicing with a negative step

# %%
device_id = "SN-A1B2C3D4E5"

# a. Extract the serial prefix ("SN-") and suffix ("A1B2C3D4E5") using slicing
prefix = device_id[:3]
suffix = device_id[3:]
print("prefix: ", prefix, ", suffix: ", suffix)

# b. Retrieve just the last three characters ("4E5") using negative indexing
last_three = device_id[-3:]
print(last_three)

# c. Reverse the entire string using slicing with a negative step
reversed_id = device_id[::-1]
print(reversed_id)
# Out:
# prefix:  SN- , suffix:  A1B2C3D4E5
# 4E5
# 5E4D3C2B1A-NS

# %% [markdown]
# Problem 4: Escape Sequences in Sensor Logs
#
# Escape Sequences in Sensor Logs
# Print the following two-line log using one print() call and appropriate escape sequences:
#
# Log Start: 2025-08-07 09:00:00
# Status: Temperature OK, Humidity OK
#
# Ensure the timestamp and status appear on separate lines and that the comma is escaped if needed.

# %%
print("Log Start: 2025-08-07 09:00:00\nStatus: Temperature OK, Humidity OK")
# Out:
# Log Start: 2025-08-07 09:00:00
# Status: Temperature OK, Humidity OK

# %% [markdown]
# Problem 5: Combined Loop + List Operation Challenge
#
# Combined Loop + List Operation Challenge
# Given a list of mixed data types representing readings and status flags:
#
# data = [100, "OK", 105, "FAIL", 102, "OK", 99, "OK"]
#
# a. Loop through the list and print only the numeric readings.
# b. Use list slicing to create two new lists: one for all even indices, one at odd indices.
# c. Count how many "OK" flags appear.

# %%
data = [100, "OK", 105, "FAIL", 102, "OK", 99, "OK"]

# a. Loop through the list and print only the numeric readings
for item in data:
    if type(item) == int:
        print(item)

# b. Use list slicing to create two new lists: one for all even indices, one at odd indices
even_indices = data[::2]
odd_indices = data[1::2]
print(even_indices, odd_indices)

# c. Count how many "OK" flags appear
ok_count = data.count("OK")
print(ok_count)
# Out:
# 100
# 105
# 102
# 99
# [100, 105, 102, 99] ['OK', 'FAIL', 'OK', 'OK']
# 3

# %% [markdown]
# Problem 6: Formatted Message Builder
#
# Formatted Message Builder
# Objective: Use input, escape sequences, and string formatting.

# %%
# Input: name and message
name = input("Enter your name: ")
message = input("Enter your message: ")

# Output using escape sequences and formatting
print(f"Hello {name},\nYour message was:\n\"{message}\"")
# Out:
# Enter your name: Soumya
# Enter your message: hi
# Hello Soumya,
# Your message was:
# "hi"

# %% [markdown]
# Problem 7: List Cleaner
#
# List Cleaner
# Objective: Remove all negative values from a list.

# %%
# Initial list with both positive and negative values
numbers = [12, -4, 6, -9, 0, 15, -1]

# Remove negative values using list comprehension
cleaned = [num for num in numbers if num >= 0]

# Output the cleaned list
print("Cleaned list:", cleaned)
# Out:
# Cleaned list: [12, 6, 0, 15]

# %% [markdown]
# Problem 8: Basic Email Splitter
#
# Basic Email Splitter
# Objective: Use .partition() and string indexing.

# %%
# Original email address
email = "user@example.com"

# Use .partition() to split the string at the first occurrence of "@"
username, sep, domain = email.partition("@")

# Output the results
print("Username:", username)
print("Domain:", domain)
# Out:
# Username: user
# Domain: example.com

# %% [markdown]
# Problem 9: List Sort & Search
#
# List Sort & Search
# Objective: Use list methods like .sort(), .reverse(), and .index().

# %%
# Original list of marks
marks = [88, 95, 70, 100, 76, 85]

# Sort the list in ascending order
marks.sort()
print("Sorted marks:", marks)

# Find the index of the value 100
print("Index of 100:", marks.index(100))

# Reverse the list
marks.reverse()
print("Reversed:", marks)
# Out:
# Sorted marks: [70, 76, 85, 88, 95, 100]
# Index of 100: 5
# Reversed: [100, 95, 88, 85, 76, 70]

# %% [markdown]
# Problem 10: Greeting and Validation Demo
#
# Greeting and Validation Demo

# %%
# Taking user's name and greeting them
name = input("Enter your name: ")
greeting = "Hello, " + name + "!"
print(greeting)

# Repeating a welcome message
welcome_msg = "Welcome! "
print(welcome_msg * 2)

# Checking password (case-sensitive)
password = input("Enter the admin password: ")
print("Password match:", password == "Admin@123")

# Checking password again with case-insensitive match
print("Password match (case-insensitive):", password.lower() == "admin@123".lower())

# Display length of user's name
print("Length of your name is:", len(name))
# Out:
# Enter your name: Soumya
# Hello, Soumya!
# Welcome! Welcome!
# Enter the admin password: Admin@123
# Password match: True
# Password match (case-insensitive): True
# Length of your name is: 6

# %% [markdown]
# # **DEMONSTRATION 4**

# %% [markdown]
# Problem 1: Converting a Tuple to a List and Modifying it
#
# Converting a Tuple to a List and Modifying it
#
# Question: You are given a tuple (10, 20, 30). How can you change the value 20 to 50 using list conversion?

# %%
tuple1 = (10, 20, 30)
list1 = list(tuple1)
list1[1] = 50
print(list1)
# Out:
# [10, 50, 30]

# %% [markdown]
# Problem 2: Using a Dictionary as a Lookup Table
#
# Using a Dictionary as a Lookup Table
#
# Question: A dictionary stores student marks in subjects. How can you retrieve the marks for "Science" from the dictionary?

# %%
marks = {"Math": 85, "Science": 90, "English": 80}
print(marks["Science"])
# Out:
# 90

# %% [markdown]
# Problem 3: Using a Set to Remove Duplicates from a list
#
# Using a Set to Remove Duplicates from a list
#
# Question: You have a list with repeated numbers: [1, 2, 2, 3, 4, 4, 5].
# How can you remove all duplicates and display only unique numbers?

# %%
numbers = [1, 2, 2, 3, 4, 4, 5]
unique = set(numbers)
print(unique)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Problem 4: Accessing Tuple Elements Using Both Indexing Types
#
# Accessing Tuple Elements Using Both Indexing Types
#
# Question: Given a tuple: t = ('apple', 'banana', 'cherry', 'date')
# How would you access the second element using positive indexing and the second last element using negative indexing?

# %%
t = ('apple', 'banana', 'cherry', 'date')
print(t[1])    # positive index
print(t[-2])   # negative index
# Out:
# banana
# cherry

# %% [markdown]
# Problem 5: Converting Different Data Types to Sets
#
# Converting Different Data Types to Sets
#
# Question: You have a string and a tuple, and you want to convert them into sets to remove duplicates and access unique values.
# a. Convert the string "Success" into a set.
# b. Convert the tuple (10, 20, 10, 30, 20) into a set and observe the unique elements.

# %%
# a. Converting string to set
string1 = "Success"
set1 = set(string1)
print("Set from string:", set1)

# b. Converting tuple to set
tuple1 = (10, 20, 10, 30, 20)
set2 = set(tuple1)
print("Set from tuple:", set2)
# Out:
# Set from string: {'e', 'u', 's', 'S', 'c'}
# Set from tuple: {10, 20, 30}

# %% [markdown]
# Problem 6: Modifying and Iterating Through a Dictionary
#
# Modifying and Iterating Through a Dictionary
#
# Question: You are managing a student's data and need to update their marks and print both keys and values.
# a. Update the student's marks from 75 to 85.
# b. Print all the keys and values from the dictionary.

# %%
student = {"name": "Anita", "marks": 75}

# a. Update marks
student["marks"] = 85

# b. Print keys and values
print("Updated Student Info:")
for key in student:
    print(key, ":", student[key])
# Out:
# Updated Student Info:
# name : Anita
# marks : 85

# %% [markdown]
# Problem 7: Creating and Modifying Sets
#
# Creating and Modifying Sets
#
# Question: You need to create a set of numbers, add a new number to it, and ensure duplicates aren't added.
# a. Create a set with numbers {2, 4, 6, 8}.
# b. Add the number 10.
# c. Try adding the number 6 again and observe what happens.

# %%
numbers = {2, 4, 6, 8}

# Add new number
numbers.add(10)

# Try to add duplicate
numbers.add(6)

print("Updated set:", numbers)
# Out:
# Updated set: {2, 4, 6, 8, 10}

# %% [markdown]
# Problem 8: Tuple and Dictionary Iteration
#
# Tuple and Dictionary Iteration
#
# Question: You have a tuple and a dictionary and want to print each element using a for loop.
# a. Iterate through the tuple (5, 10, 15).
# b. Print all keys and values of a dictionary containing {"course": "Python", "duration": "3 months"}

# %%
# a. Tuple iteration
tuple1 = (5, 10, 15)
print("Tuple values:")
for value in tuple1:
    print(value)

# b. Dictionary iteration
course_info = {"course": "Python", "duration": "3 months"}
print("Course Info:")
for key in course_info:
    print(key, "->", course_info[key])
# Out:
# Tuple values:
# 5
# 10
# 15
# Course Info:
# course -> Python
# duration -> 3 months

# %% [markdown]
# Problem 9: Tuple Method - Counting Occurrences
#
# Tuple Method - Counting Occurrences
#
# Question: You are given a tuple with repeated elements. How can you count how many times a particular value appears?

# %%
t = (2, 4, 5, 2, 3, 2, 4, 2)
print(t.count(2))
# Out:
# 4

# %% [markdown]
# Problem 10: Converting Dictionary and Set to Tuples
#
# Converting Dictionary and Set to Tuples
#
# Question: How can you convert a dictionary and a set to a tuple?
# a. convert the dictionary {1: "one", 2: "Two"} to a tuple and print.
# b. convert the set {1, 2, 3} to a tuple and print.

# %%
# a. Dictionary to tuple
dict1 = {1: "one", 2: "Two"}
tuple1 = tuple(dict1)
print("Tuple from dictionary:", tuple1)

# b. Set to tuple
set1 = {1, 2, 3}
tuple2 = tuple(set1)
print("Tuple from set:", tuple2)
# Out:
# Tuple from dictionary: (1, 2)
# Tuple from set: (1, 2, 3)

# %% [markdown]
# # **DEMONSTRATION 5**

# %% [markdown]
# Problem 1: Sum of Two Numbers from User Input

# %%
def sum(a,b):
    return a+b

a = int(input("Enter a:"))
b = int(input("Enter b:"))
print("Sum = ", sum(a,b))
# Out:
# Enter a:12
# Enter b:17
# Sum =  29

# %% [markdown]
# Problem 2: Function with Default Argument

# %%
def greet(name="Guest"):
    print("Hello,", name)

greet()
greet("Alice")
# Out:
# Hello, Guest
# Hello, Alice

# %% [markdown]
# Problem 3: Keyword-Length Arguments

# %%
def ab(**a):
    for i in a.items():
        print(i)

ab(a=10, b=20, c="Hello")
# Out:
# ('a', 10)
# ('b', 20)
# ('c', 'Hello')

# %% [markdown]
# Problem 4: Global and Local Variables

# %%
def display():
    a = 10
    print("Local Variable a =", a)

a = 20
print("Global Variable a =", a)
display()
# Out:
# Global Variable a = 20
# Local Variable a = 10

# %% [markdown]
# Problem 5: Function Returning a Value

# %%
def find_square(num):
    result = num * num
    return result

square = find_square(3)
print("Square:", square)
# Out:
# Square: 9

# %% [markdown]
# Problem 6: Function with Two Arguments

# %%
def add_numbers(num1, num2):
    sum = num1 + num2
    print("Sum:", sum)

add_numbers(5, 4)
# Out:
# Sum: 9

# %% [markdown]
# Problem 7: Variable Keyword Arguments using kwargs

# %%
def display_info(**kwargs):
    for key, value in kwargs.items():
        print(f'{key}: {value}')

display_info(name="Alice", age=30, city="New York")
# Out:
# name: Alice
# age: 30
# city: New York

# %% [markdown]
# Problem 8: Power Function with Default Parameter

# %%
def power(base, exponent=2):
    return base ** exponent

print(power(3))
print(power(3, 3))
# Out:
# 9
# 27

# %% [markdown]
# Problem 9: Function with Type Annotations

# %%
def add(num1: int, num2: int):
    """Add two numbers"""
    num3 = num1 + num2
    return num3

# Driver code
num1, num2 = 5, 15
ans = add(num1, num2)
print(f"The addition of {num1} and {num2} results {ans}.")
# Out:
# The addition of 5 and 15 results 20.

# %% [markdown]
# Problem 10: Factorial Calculation (Reverse Display)

# %%
def factorial_with_recursion(n):
    if n == 1:
        return 1
    return n * factorial_with_recursion(n - 1)

print(factorial_with_recursion(2))
print(factorial_with_recursion(3))
print(factorial_with_recursion(4))
print(factorial_with_recursion(5))
# Out:
# 2
# 6
# 24
# 120
